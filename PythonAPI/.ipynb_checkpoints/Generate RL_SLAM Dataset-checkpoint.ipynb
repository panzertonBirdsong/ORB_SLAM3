# %%
import os
import time

import tools
import benchmarks as bm
from poseEvaluation import PoseErrorEvaluator
from evo.core import metrics
# Out:
# [DEBUG][2024-02-08 00:26:56,771][log.configure_logging():112]
# System info:
# Python 3.8.17
# Linux-6.5.0-15-generic-x86_64-with-glibc2.17
# slam@slam-TensorBook

# %%
benchmark_list = ["SenseTime","TUMRGBD1", "TUMRGBD2", "TUMRGBD3"]
#benchmark_list = ["SenseTime", "TUMRGBD1", "TUMRGBD2", "TUMRGBD3"]
benchmark_list = ["SenseTime"]
root_dir = "/home/slam/Projects/ORB_SLAM3_DRL/"
trials = 3
delta = 30
max_diff = 0.05
max_null_length = 10

os.chdir(root_dir)
root_dir = "."

# %%
poseErrorEvaluator = PoseErrorEvaluator(root_dir, delta, max_diff, max_null_length)

# %%
tools.delete_files_in_folder("./logs")
tools.delete_files_in_folder("./data")
tools.delete_files_in_folder("./figures")
# Out:
# Deleted: ./logs/ground_truth.txt
# Deleted: ./logs/trajectory.txt
# All files deleted successfully.
# All files deleted successfully.
# All files deleted successfully.

# %%
for i, benchmark in enumerate(benchmark_list):
    benchmarkClass = bm.benchmark_factory[benchmark]
    benchmarkObject = benchmarkClass(root_dir)
    benchmarkObject.generate_script()
    scriptList = benchmarkObject.get_script()
    for j, scriptDict in enumerate(scriptList):    
        time.sleep(1)
        benchmark = scriptDict["benchmark"]
        trajectory = scriptDict["trajectory"]
        benchmarkObject.copy_ground_truth_traj(scriptDict["trajectory"])
        
        for trial in range(0, trials):
            # Baseline
            baseline_df, baseline_df_traj, baseline_initial_rows = benchmarkObject.load_n_save_baseline_estimated_traj(trajectory, trial)
            time.sleep(1)

            poseErrorEvaluator = PoseErrorEvaluator(root_dir, delta, max_diff, max_null_length)

            poseErrorEvaluator.load_trajectory()
            traj_est, traj_ref = poseErrorEvaluator.get_traj_w_gt()

            rpe_metric = poseErrorEvaluator.calculate_RE()
            poseErrorEvaluator.merge_feature_with_label(trajectory)
            merged_df = poseErrorEvaluator.get_feature_w_label()
            error_df = poseErrorEvaluator.get_error_df()


            poseErrorEvaluator.plot_aligned_trajectory(traj_est, traj_ref, benchmark, trajectory, trial, "Baseline")
            poseErrorEvaluator.plot_error(error_df, delta, benchmark, trajectory, trial, "Baseline")

            poseErrorEvaluator.plot_trajectory_with_error(rpe_metric, traj_ref, traj_est,
                                                          benchmark, trajectory, trial, "Baseline")


            #df_data = poseErrorEvaluator.attach_label_2_features(delta, error, df)
            #time.sleep(1)

            merged_df.to_csv("./data/baseline_{}_{}_{}.csv".format(benchmark,trajectory, trial), sep=',', index=False, header=True)
            time.sleep(2)
            
            
            # RL enabled
            rl_df, rl_df_traj, rl_initial_rows = benchmarkObject.load_n_save_rl_estimated_traj(trajectory, trial)
            time.sleep(1)
            
            poseErrorEvaluator = PoseErrorEvaluator(root_dir, delta, max_diff, max_null_length)
            
            poseErrorEvaluator.load_trajectory()
            traj_est, traj_ref = poseErrorEvaluator.get_traj_w_gt()
            
            rpe_metric = poseErrorEvaluator.calculate_RE(pose_relation=metrics.PoseRelation.point_distance)
            
            poseErrorEvaluator.merge_feature_with_label(trajectory, trial)
            merged_df = poseErrorEvaluator.get_feature_w_label()
            error_df = poseErrorEvaluator.get_error_df()
            
        
            poseErrorEvaluator.plot_aligned_trajectory(traj_est, traj_ref, benchmark, trajectory, trial, "RL")
            poseErrorEvaluator.plot_error(error_df, delta, benchmark, trajectory, trial, "RL")
            
            poseErrorEvaluator.plot_trajectory_with_error(rpe_metric, traj_ref, traj_est,
                                                          benchmark, trajectory, trial, "RL")

            merged_df.to_csv("./data/RL_{}_{}_{}.csv".format(benchmark,trajectory,trial), sep=',', index=False, header=True)
            time.sleep(1)
            
            reward_df = poseErrorEvaluator.calculate_reward(trajectory, trial)
            reward_df.to_csv("./RL_Train/RL_{}_{}_{}.csv".format(benchmark,trajectory,trial), sep=',', index=False, header=True)
# Out:
# [DEBUG][2024-02-08 00:27:02,380][file_interface.read_tum_trajectory_file():117]
# Loaded 1554 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:02,449][file_interface.read_tum_trajectory_file():117]
# Loaded 24578 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 1005], [1005, 1554]]
# Original estimated subtrajectory length: 1005
# [DEBUG][2024-02-08 00:27:02,478][sync.associate_trajectories():110]
# Found 1005 of max. 1005 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:02,479][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:02,538][trajectory.align():214]
# Rotation of alignment:
# [[-0.14525576  0.98111172  0.12775192]
#  [ 0.84955052  0.18986199 -0.49215479]
#  [-0.50711406  0.03704339 -0.86108252]]
# Translation of alignment:
# [-0.48805122  2.06917337  1.23543264]
# [DEBUG][2024-02-08 00:27:02,539][trajectory.align():216]
# Scale correction: 1.4151563873873647
# Original estimated subtrajectory length: 549
# [DEBUG][2024-02-08 00:27:02,579][sync.associate_trajectories():110]
# Found 549 of max. 549 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:02,579][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:02,581][trajectory.align():214]
# Rotation of alignment:
# [[-0.17310848  0.9848769   0.00713705]
#  [ 0.83882881  0.15122787 -0.5229688 ]
#  [-0.51613921 -0.08454358 -0.85232195]]
# Translation of alignment:
# [-0.40587355  2.229072    1.174786  ]
# [DEBUG][2024-02-08 00:27:02,582][trajectory.align():216]
# Scale correction: 1.3860600380402983
# [DEBUG][2024-02-08 00:27:02,614][sync.associate_trajectories():110]
# Found 1554 of max. 1554 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (1554 poses)  with ground truth 1554 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:02,626][metrics.id_pairs_from_delta():469]
# Found 1524 pairs with delta 30 (frames) among 1554 poses using all pairs.
# [DEBUG][2024-02-08 00:27:02,652][metrics.process_data():313]
# Compared 1524 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:02,653][metrics.process_data():319]
# Calculating RPE for translation part pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:02,916][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:02,920][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00  9.18667408e-16 -1.57348005e-15]
#  [-1.06929747e-15  1.00000000e+00  2.44424458e-16]
#  [ 1.60807925e-15 -2.80226132e-16  1.00000000e+00]]
# Translation of alignment:
# [ 1.16573418e-15 -1.55431223e-15  4.66293670e-15]
# [DEBUG][2024-02-08 00:27:02,921][trajectory.align():216]
# Scale correction: 1.0
# [DEBUG][2024-02-08 00:27:06,455][file_interface.read_tum_trajectory_file():117]
# Loaded 1554 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:06,526][file_interface.read_tum_trajectory_file():117]
# Loaded 24578 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 638], [638, 1444], [1444, 1554]]
# Original estimated subtrajectory length: 638
# [DEBUG][2024-02-08 00:27:06,544][sync.associate_trajectories():110]
# Found 638 of max. 638 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:06,545][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:06,549][trajectory.align():214]
# Rotation of alignment:
# [[-0.17331091  0.98424452  0.03501496]
#  [ 0.84856594  0.16727704 -0.50195043]
#  [-0.49989916 -0.05728098 -0.86418732]]
# Translation of alignment:
# [-0.43321543  2.11046409  1.24062933]
# [DEBUG][2024-02-08 00:27:06,549][trajectory.align():216]
# Scale correction: 1.496587283434599
# Original estimated subtrajectory length: 806
# [DEBUG][2024-02-08 00:27:06,576][sync.associate_trajectories():110]
# Found 806 of max. 806 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:06,576][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:06,579][trajectory.align():214]
# Rotation of alignment:
# [[ 0.05563396 -0.99835502 -0.01386087]
#  [-0.69709798 -0.04877745  0.71531474]
#  [-0.71481415 -0.03013341 -0.69866494]]
# Translation of alignment:
# [-0.33188705 -0.10860671  1.34536581]
# [DEBUG][2024-02-08 00:27:06,579][trajectory.align():216]
# Scale correction: 2.5823463556588684
# Original estimated subtrajectory length: 110
# [DEBUG][2024-02-08 00:27:06,595][sync.associate_trajectories():110]
# Found 110 of max. 110 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:06,596][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# [DEBUG][2024-02-08 00:27:06,616][sync.associate_trajectories():110]
# Found 1444 of max. 1444 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (1444 poses)  with ground truth 1444 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:06,629][metrics.id_pairs_from_delta():469]
# Found 1414 pairs with delta 30 (frames) among 1444 poses using all pairs.
# [DEBUG][2024-02-08 00:27:06,634][metrics.process_data():313]
# Compared 0 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:06,634][metrics.process_data():319]
# Calculating RPE for point distance pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:06,652][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:06,656][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00  1.25856127e-16 -3.70901525e-15]
#  [-2.36799327e-16  1.00000000e+00 -1.92224521e-16]
#  [ 3.68951936e-15  1.71437538e-16  1.00000000e+00]]
# Translation of alignment:
# [ 5.10702591e-15 -6.66133815e-16  3.55271368e-15]
# [DEBUG][2024-02-08 00:27:06,657][trajectory.align():216]
# Scale correction: 0.9999999999999993
# /home/slam/Projects/ORB_SLAM3_DRL/PythonAPI/poseEvaluation.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_error_df.rename(columns={'RelativeError': 'BaseRelativeError'}, inplace=True)
# [DEBUG][2024-02-08 00:27:09,112][file_interface.read_tum_trajectory_file():117]
# Loaded 1554 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:09,183][file_interface.read_tum_trajectory_file():117]
# Loaded 24578 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 656], [656, 892], [892, 1282], [1282, 1440], [1440, 1554]]
# Original estimated subtrajectory length: 656
# [DEBUG][2024-02-08 00:27:09,201][sync.associate_trajectories():110]
# Found 656 of max. 656 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:09,202][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:09,204][trajectory.align():214]
# Rotation of alignment:
# [[-0.18329406  0.98268722  0.02700198]
#  [ 0.84858498  0.17202823 -0.50030973]
#  [-0.49629308 -0.06879033 -0.86542537]]
# Translation of alignment:
# [-0.43244736  2.10973951  1.24062432]
# [DEBUG][2024-02-08 00:27:09,205][trajectory.align():216]
# Scale correction: 1.4593897447549546
# Original estimated subtrajectory length: 236
# [DEBUG][2024-02-08 00:27:09,220][sync.associate_trajectories():110]
# Found 236 of max. 236 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:09,221][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:09,222][trajectory.align():214]
# Rotation of alignment:
# [[ 0.0468213  -0.99829261  0.03492329]
#  [-0.72076604 -0.00955776  0.69311252]
#  [-0.69159532 -0.05762395 -0.71998291]]
# Translation of alignment:
# [-0.37483558 -0.12323565  1.34870293]
# [DEBUG][2024-02-08 00:27:09,222][trajectory.align():216]
# Scale correction: 2.755648415994676
# Original estimated subtrajectory length: 390
# [DEBUG][2024-02-08 00:27:09,232][sync.associate_trajectories():110]
# Found 390 of max. 390 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:09,233][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:09,235][trajectory.align():214]
# Rotation of alignment:
# [[-0.08491935  0.99614332 -0.02207249]
#  [ 0.71006207  0.04496102 -0.70270219]
#  [-0.69899969 -0.07534585 -0.71114164]]
# Translation of alignment:
# [-0.44418323  1.44428551  1.33796835]
# [DEBUG][2024-02-08 00:27:09,235][trajectory.align():216]
# Scale correction: 1.9725738952959864
# Original estimated subtrajectory length: 158
# [DEBUG][2024-02-08 00:27:09,245][sync.associate_trajectories():110]
# Found 158 of max. 158 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:09,245][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:09,246][trajectory.align():214]
# Rotation of alignment:
# [[ 0.02591522 -0.99374098  0.10866121]
#  [-0.7202315   0.05681937  0.69140302]
#  [-0.69324958 -0.09617909 -0.71425108]]
# Translation of alignment:
# [-0.44649597  0.48379726  1.33321708]
# [DEBUG][2024-02-08 00:27:09,246][trajectory.align():216]
# Scale correction: 1.9849369549458709
# Original estimated subtrajectory length: 114
# [DEBUG][2024-02-08 00:27:09,254][sync.associate_trajectories():110]
# Found 114 of max. 114 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:09,254][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# [DEBUG][2024-02-08 00:27:09,275][sync.associate_trajectories():110]
# Found 1440 of max. 1440 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (1440 poses)  with ground truth 1440 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:09,287][metrics.id_pairs_from_delta():469]
# Found 1410 pairs with delta 30 (frames) among 1440 poses using all pairs.
# [DEBUG][2024-02-08 00:27:09,292][metrics.process_data():313]
# Compared 0 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:09,293][metrics.process_data():319]
# Calculating RPE for point distance pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:09,310][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:09,314][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00  5.74672843e-17  3.42770994e-15]
#  [-2.58486937e-16  1.00000000e+00 -1.32821915e-16]
#  [-3.49158923e-15  1.55579453e-16  1.00000000e+00]]
# Translation of alignment:
# [-7.88258347e-15  3.99680289e-15 -5.10702591e-15]
# [DEBUG][2024-02-08 00:27:09,315][trajectory.align():216]
# Scale correction: 1.0
# /home/slam/Projects/ORB_SLAM3_DRL/PythonAPI/poseEvaluation.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_error_df.rename(columns={'RelativeError': 'BaseRelativeError'}, inplace=True)
# [DEBUG][2024-02-08 00:27:13,028][file_interface.read_tum_trajectory_file():117]
# Loaded 3470 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:13,176][file_interface.read_tum_trajectory_file():117]
# Loaded 48189 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 2108], [2108, 2431], [2431, 2677], [2677, 2698], [2698, 3470]]
# Original estimated subtrajectory length: 2108
# [DEBUG][2024-02-08 00:27:13,253][sync.associate_trajectories():110]
# Found 2108 of max. 2108 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:13,254][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:13,259][trajectory.align():214]
# Rotation of alignment:
# [[-0.12311229  0.94903987  0.29011497]
#  [ 0.19405285  0.30971722 -0.93081617]
#  [-0.97323525 -0.05829727 -0.22229388]]
# Translation of alignment:
# [ 1.40759311 -0.25110256  1.55643812]
# [DEBUG][2024-02-08 00:27:13,260][trajectory.align():216]
# Scale correction: 1.5715028830698432
# Original estimated subtrajectory length: 323
# [DEBUG][2024-02-08 00:27:13,308][sync.associate_trajectories():110]
# Found 323 of max. 323 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:13,309][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:13,310][trajectory.align():214]
# Rotation of alignment:
# [[-0.58290385  0.46100974  0.66909873]
#  [-0.04886655  0.80208422 -0.59520833]
#  [-0.81107038 -0.37964578 -0.44501003]]
# Translation of alignment:
# [-0.44133945  0.54185154  1.57485456]
# [DEBUG][2024-02-08 00:27:13,311][trajectory.align():216]
# Scale correction: 3.3324028720630308
# Original estimated subtrajectory length: 246
# [DEBUG][2024-02-08 00:27:13,325][sync.associate_trajectories():110]
# Found 246 of max. 246 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:13,326][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:13,327][trajectory.align():214]
# Rotation of alignment:
# [[-0.12005063  0.93841243  0.32399069]
#  [ 0.20058644  0.34254808 -0.91783762]
#  [-0.97229261 -0.04519884 -0.22935592]]
# Translation of alignment:
# [ 1.00320842 -0.26731342  1.51584397]
# [DEBUG][2024-02-08 00:27:13,327][trajectory.align():216]
# Scale correction: 1.5861425025092353
# Original estimated subtrajectory length: 21
# [DEBUG][2024-02-08 00:27:13,337][sync.associate_trajectories():110]
# Found 21 of max. 21 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:13,337][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 772
# [DEBUG][2024-02-08 00:27:13,369][sync.associate_trajectories():110]
# Found 772 of max. 772 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:13,370][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:13,373][trajectory.align():214]
# Rotation of alignment:
# [[-0.16470983  0.93400984  0.3170115 ]
#  [ 0.14566892  0.3409115  -0.92874104]
#  [-0.97552613 -0.10679405 -0.19220768]]
# Translation of alignment:
# [ 0.99498568 -0.23579798  1.50662569]
# [DEBUG][2024-02-08 00:27:13,373][trajectory.align():216]
# Scale correction: 1.5170788750208777
# [DEBUG][2024-02-08 00:27:13,492][sync.associate_trajectories():110]
# Found 3449 of max. 3449 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (3449 poses)  with ground truth 3449 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:13,522][metrics.id_pairs_from_delta():469]
# Found 3419 pairs with delta 30 (frames) among 3449 poses using all pairs.
# [DEBUG][2024-02-08 00:27:13,580][metrics.process_data():313]
# Compared 3419 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:13,581][metrics.process_data():319]
# Calculating RPE for translation part pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:13,613][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:13,622][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00 -2.26235257e-16  8.17966520e-16]
#  [ 1.83835152e-16  1.00000000e+00  2.00191014e-15]
#  [-8.13287851e-16 -1.98193402e-15  1.00000000e+00]]
# Translation of alignment:
# [-6.66133815e-15 -2.10942375e-15  1.39888101e-14]
# [DEBUG][2024-02-08 00:27:13,623][trajectory.align():216]
# Scale correction: 1.0000000000000016
# [DEBUG][2024-02-08 00:27:17,272][file_interface.read_tum_trajectory_file():117]
# Loaded 3470 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:17,412][file_interface.read_tum_trajectory_file():117]
# Loaded 48189 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 1030], [1030, 1187], [1187, 2103], [2103, 2382], [2382, 2666], [2666, 2892], [2892, 3293], [3293, 3304], [3304, 3470]]
# Original estimated subtrajectory length: 1030
# [DEBUG][2024-02-08 00:27:17,460][sync.associate_trajectories():110]
# Found 1030 of max. 1030 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,461][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,464][trajectory.align():214]
# Rotation of alignment:
# [[-0.54740969 -0.43125599  0.71718959]
#  [ 0.31760712 -0.89993833 -0.29872517]
#  [ 0.77425342  0.06425946  0.62960493]]
# Translation of alignment:
# [ 1.64230728 -0.16645409  1.56202708]
# [DEBUG][2024-02-08 00:27:17,464][trajectory.align():216]
# Scale correction: 0.3609160219609774
# Original estimated subtrajectory length: 157
# [DEBUG][2024-02-08 00:27:17,488][sync.associate_trajectories():110]
# Found 157 of max. 157 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,488][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,490][trajectory.align():214]
# Rotation of alignment:
# [[-0.34523963  0.56070814  0.75260613]
#  [-0.11336579  0.77112542 -0.6265092 ]
#  [-0.93164253 -0.30161559 -0.20265793]]
# Translation of alignment:
# [ 0.54643907 -0.49007327  1.62869634]
# [DEBUG][2024-02-08 00:27:17,490][trajectory.align():216]
# Scale correction: 1.1941305123559343
# Original estimated subtrajectory length: 916
# [DEBUG][2024-02-08 00:27:17,523][sync.associate_trajectories():110]
# Found 916 of max. 916 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,524][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,527][trajectory.align():214]
# Rotation of alignment:
# [[ 0.51120759  0.62849486 -0.58622607]
#  [ 0.30502766 -0.7703609  -0.55991269]
#  [-0.80350789  0.10741645 -0.58552265]]
# Translation of alignment:
# [ 1.46884669 -0.49464871  1.59842895]
# [DEBUG][2024-02-08 00:27:17,527][trajectory.align():216]
# Scale correction: 1.7344358439906553
# Original estimated subtrajectory length: 279
# [DEBUG][2024-02-08 00:27:17,551][sync.associate_trajectories():110]
# Found 279 of max. 279 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,552][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,553][trajectory.align():214]
# Rotation of alignment:
# [[-0.57641118  0.47203354  0.6670341 ]
#  [ 0.0232305   0.82541926 -0.56404201]
#  [-0.81682954 -0.30962458 -0.48674646]]
# Translation of alignment:
# [-0.48382556  0.55715341  1.5749736 ]
# [DEBUG][2024-02-08 00:27:17,554][trajectory.align():216]
# Scale correction: 3.1562808734255543
# Original estimated subtrajectory length: 284
# [DEBUG][2024-02-08 00:27:17,569][sync.associate_trajectories():110]
# Found 284 of max. 284 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,570][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,571][trajectory.align():214]
# Rotation of alignment:
# [[ 0.59911757 -0.39802952 -0.69471623]
#  [ 0.0712945  -0.83771081  0.54144039]
#  [-0.79748055 -0.37391589 -0.47350995]]
# Translation of alignment:
# [ 1.67190673 -0.36225461  1.594811  ]
# [DEBUG][2024-02-08 00:27:17,571][trajectory.align():216]
# Scale correction: 2.7835015787156596
# Original estimated subtrajectory length: 226
# [DEBUG][2024-02-08 00:27:17,584][sync.associate_trajectories():110]
# Found 226 of max. 226 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,585][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,586][trajectory.align():214]
# Rotation of alignment:
# [[-0.53927022  0.48633145  0.68750953]
#  [ 0.17302667  0.86296003 -0.47472283]
#  [-0.82416588 -0.13704639 -0.54951695]]
# Translation of alignment:
# [-0.13051214  0.52018084  1.60415198]
# [DEBUG][2024-02-08 00:27:17,586][trajectory.align():216]
# Scale correction: 3.3740569377994496
# Original estimated subtrajectory length: 401
# [DEBUG][2024-02-08 00:27:17,604][sync.associate_trajectories():110]
# Found 401 of max. 401 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,604][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,606][trajectory.align():214]
# Rotation of alignment:
# [[ 0.59626574 -0.41525543 -0.68704446]
#  [ 0.06518274 -0.82795516  0.55699323]
#  [-0.80013647 -0.37689942 -0.46661381]]
# Translation of alignment:
# [ 1.59971769 -0.44716115  1.5745527 ]
# [DEBUG][2024-02-08 00:27:17,606][trajectory.align():216]
# Scale correction: 2.6663925128291024
# Original estimated subtrajectory length: 11
# [DEBUG][2024-02-08 00:27:17,614][sync.associate_trajectories():110]
# Found 11 of max. 11 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,615][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,616][trajectory.align():214]
# Rotation of alignment:
# [[-0.20192419  0.41889038  0.88530078]
#  [ 0.52058425  0.81155936 -0.2652611 ]
#  [-0.82958945  0.40731101 -0.3819412 ]]
# Translation of alignment:
# [-0.20817586  0.51212337  1.47045221]
# [DEBUG][2024-02-08 00:27:17,616][trajectory.align():216]
# Scale correction: 2.862276318197485
# Original estimated subtrajectory length: 166
# [DEBUG][2024-02-08 00:27:17,622][sync.associate_trajectories():110]
# Found 166 of max. 166 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:17,623][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,624][trajectory.align():214]
# Rotation of alignment:
# [[-0.51649808  0.50975812  0.68802354]
#  [ 0.22372319  0.85592099 -0.4662051 ]
#  [-0.82654562 -0.08686722 -0.55612626]]
# Translation of alignment:
# [0.30655294 0.33395383 1.60855032]
# [DEBUG][2024-02-08 00:27:17,624][trajectory.align():216]
# Scale correction: 2.5814306779196334
# [DEBUG][2024-02-08 00:27:17,734][sync.associate_trajectories():110]
# Found 3470 of max. 3470 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (3470 poses)  with ground truth 3470 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:17,760][metrics.id_pairs_from_delta():469]
# Found 3440 pairs with delta 30 (frames) among 3470 poses using all pairs.
# [DEBUG][2024-02-08 00:27:17,773][metrics.process_data():313]
# Compared 0 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:17,773][metrics.process_data():319]
# Calculating RPE for point distance pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:17,800][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:17,809][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00 -8.01184861e-16  3.35171004e-15]
#  [ 1.03456698e-15  1.00000000e+00  6.34799590e-15]
#  [-3.36820668e-15 -6.35506557e-15  1.00000000e+00]]
# Translation of alignment:
# [ 1.73194792e-14 -1.49602553e-14 -2.97539771e-14]
# [DEBUG][2024-02-08 00:27:17,810][trajectory.align():216]
# Scale correction: 1.000000000000001
# /home/slam/Projects/ORB_SLAM3_DRL/PythonAPI/poseEvaluation.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_error_df.rename(columns={'RelativeError': 'BaseRelativeError'}, inplace=True)
# [DEBUG][2024-02-08 00:27:20,542][file_interface.read_tum_trajectory_file():117]
# Loaded 3470 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:20,683][file_interface.read_tum_trajectory_file():117]
# Loaded 48189 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 1327], [1327, 2106], [2106, 2396], [2396, 2667], [2667, 2793], [2793, 2915], [2915, 3221], [3221, 3470]]
# Original estimated subtrajectory length: 1327
# [DEBUG][2024-02-08 00:27:20,740][sync.associate_trajectories():110]
# Found 1327 of max. 1327 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:20,741][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:20,744][trajectory.align():214]
# Rotation of alignment:
# [[-0.05007688  0.9982402  -0.0317619 ]
#  [ 0.14994525 -0.02392693 -0.98840474]
#  [-0.9874253  -0.05425877 -0.14848319]]
# Translation of alignment:
# [ 1.83557349 -0.15144386  1.56008831]
# [DEBUG][2024-02-08 00:27:20,745][trajectory.align():216]
# Scale correction: 1.37617682263553
# Original estimated subtrajectory length: 779
# [DEBUG][2024-02-08 00:27:20,791][sync.associate_trajectories():110]
# Found 779 of max. 779 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:20,792][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:20,795][trajectory.align():214]
# Rotation of alignment:
# [[-0.44702829  0.62186899  0.64299664]
#  [ 0.19153621  0.76868947 -0.61027075]
#  [-0.87377319 -0.14965115 -0.46273636]]
# Translation of alignment:
# [ 0.63417659 -0.51264494  1.61788976]
# [DEBUG][2024-02-08 00:27:20,795][trajectory.align():216]
# Scale correction: 2.073498880969172
# Original estimated subtrajectory length: 290
# [DEBUG][2024-02-08 00:27:20,818][sync.associate_trajectories():110]
# Found 290 of max. 290 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:20,819][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:20,820][trajectory.align():214]
# Rotation of alignment:
# [[-0.23135762 -0.16875565  0.95812065]
#  [-0.64489488 -0.71077324 -0.28091279]
#  [ 0.72841214 -0.68287842  0.05561315]]
# Translation of alignment:
# [-0.50496044  0.58112304  1.53551523]
# [DEBUG][2024-02-08 00:27:20,821][trajectory.align():216]
# Scale correction: 4.164003241061017
# Original estimated subtrajectory length: 271
# [DEBUG][2024-02-08 00:27:20,835][sync.associate_trajectories():110]
# Found 271 of max. 271 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:20,836][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:20,838][trajectory.align():214]
# Rotation of alignment:
# [[ 0.3840138  -0.49870098 -0.77706546]
#  [-0.30187312 -0.8631538   0.40476925]
#  [-0.87258583  0.0791382  -0.48200739]]
# Translation of alignment:
# [ 1.5997891  -0.30927305  1.58701536]
# [DEBUG][2024-02-08 00:27:20,838][trajectory.align():216]
# Scale correction: 3.300524165845666
# Original estimated subtrajectory length: 126
# [DEBUG][2024-02-08 00:27:20,848][sync.associate_trajectories():110]
# Found 126 of max. 126 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:20,849][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:20,850][trajectory.align():214]
# Rotation of alignment:
# [[-0.68810632  0.31551839  0.65342011]
#  [-0.296139    0.69998567 -0.64986287]
#  [-0.6624284  -0.64067793 -0.38822727]]
# Translation of alignment:
# [-0.19187964  0.54771158  1.60562913]
# [DEBUG][2024-02-08 00:27:20,850][trajectory.align():216]
# Scale correction: 5.673517145108041
# Original estimated subtrajectory length: 122
# [DEBUG][2024-02-08 00:27:20,857][sync.associate_trajectories():110]
# Found 122 of max. 122 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:20,858][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:20,858][trajectory.align():214]
# Rotation of alignment:
# [[-0.70008006  0.52115671  0.488143  ]
#  [ 0.32652951  0.84159962 -0.4302192 ]
#  [-0.63503258 -0.14179479 -0.75936016]]
# Translation of alignment:
# [0.34550009 0.418246   2.66406686]
# [DEBUG][2024-02-08 00:27:20,859][trajectory.align():216]
# Scale correction: 3.5971438712410913
# Original estimated subtrajectory length: 306
# [DEBUG][2024-02-08 00:27:20,872][sync.associate_trajectories():110]
# Found 306 of max. 306 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:20,872][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:20,874][trajectory.align():214]
# Rotation of alignment:
# [[ 0.3456505  -0.50758724 -0.78922805]
#  [-0.41157634 -0.83785721  0.35860872]
#  [-0.84328563  0.20087431 -0.49851666]]
# Translation of alignment:
# [ 1.55422344 -0.39465728  1.58189003]
# [DEBUG][2024-02-08 00:27:20,874][trajectory.align():216]
# Scale correction: 3.2573885309071895
# Original estimated subtrajectory length: 249
# [DEBUG][2024-02-08 00:27:20,889][sync.associate_trajectories():110]
# Found 249 of max. 249 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:20,889][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:20,891][trajectory.align():214]
# Rotation of alignment:
# [[-0.52895797  0.60027453  0.59989495]
#  [ 0.26284511  0.78800556 -0.55674023]
#  [-0.80691754 -0.13681273 -0.57460105]]
# Translation of alignment:
# [1.00134617e-03 5.69634265e-01 1.59826134e+00]
# [DEBUG][2024-02-08 00:27:20,891][trajectory.align():216]
# Scale correction: 2.3976494258716965
# [DEBUG][2024-02-08 00:27:21,001][sync.associate_trajectories():110]
# Found 3470 of max. 3470 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (3470 poses)  with ground truth 3470 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:21,029][metrics.id_pairs_from_delta():469]
# Found 3440 pairs with delta 30 (frames) among 3470 poses using all pairs.
# [DEBUG][2024-02-08 00:27:21,041][metrics.process_data():313]
# Compared 0 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:21,041][metrics.process_data():319]
# Calculating RPE for point distance pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:21,068][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:21,077][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00 -7.78178492e-16  2.02912694e-15]
#  [ 6.40637528e-16  1.00000000e+00  4.60460801e-15]
#  [-2.02912207e-15 -4.58347240e-15  1.00000000e+00]]
# Translation of alignment:
# [ 8.88178420e-15 -7.77156117e-15  4.66293670e-15]
# [DEBUG][2024-02-08 00:27:21,077][trajectory.align():216]
# Scale correction: 1.0000000000000004
# /home/slam/Projects/ORB_SLAM3_DRL/PythonAPI/poseEvaluation.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_error_df.rename(columns={'RelativeError': 'BaseRelativeError'}, inplace=True)
# [DEBUG][2024-02-08 00:27:24,880][file_interface.read_tum_trajectory_file():117]
# Loaded 1947 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:24,966][file_interface.read_tum_trajectory_file():117]
# Loaded 30406 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 1947]]
# Original estimated subtrajectory length: 1947
# [DEBUG][2024-02-08 00:27:25,010][sync.associate_trajectories():110]
# Found 1947 of max. 1947 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:25,011][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:25,016][trajectory.align():214]
# Rotation of alignment:
# [[-0.16254074  0.98223263  0.09380602]
#  [ 0.73864489  0.18416054 -0.64845094]
#  [-0.65420504 -0.03611035 -0.75545471]]
# Translation of alignment:
# [-0.59370594  2.18174682  1.2605786 ]
# [DEBUG][2024-02-08 00:27:25,017][trajectory.align():216]
# Scale correction: 2.2456199801025947
# [DEBUG][2024-02-08 00:27:25,082][sync.associate_trajectories():110]
# Found 1947 of max. 1947 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (1947 poses)  with ground truth 1947 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:25,098][metrics.id_pairs_from_delta():469]
# Found 1917 pairs with delta 30 (frames) among 1947 poses using all pairs.
# [DEBUG][2024-02-08 00:27:25,131][metrics.process_data():313]
# Compared 1917 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:25,132][metrics.process_data():319]
# Calculating RPE for translation part pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:25,155][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:25,160][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00 -1.86148665e-16 -7.78430189e-16]
#  [ 4.28103944e-16  1.00000000e+00 -7.85770737e-16]
#  [ 7.83849634e-16  7.89016995e-16  1.00000000e+00]]
# Translation of alignment:
# [4.16333634e-16 1.11022302e-15 0.00000000e+00]
# [DEBUG][2024-02-08 00:27:25,160][trajectory.align():216]
# Scale correction: 0.9999999999999976
# /home/slam/Projects/ORB_SLAM3_DRL/PythonAPI/poseEvaluation.py:285: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=(10,10))
# [DEBUG][2024-02-08 00:27:28,624][file_interface.read_tum_trajectory_file():117]
# Loaded 1947 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:28,763][file_interface.read_tum_trajectory_file():117]
# Loaded 30406 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 1580], [1580, 1873], [1873, 1947]]
# Original estimated subtrajectory length: 1580
# [DEBUG][2024-02-08 00:27:28,800][sync.associate_trajectories():110]
# Found 1580 of max. 1580 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:28,801][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:28,805][trajectory.align():214]
# Rotation of alignment:
# [[-0.15299372  0.98340172  0.09753961]
#  [ 0.74523289  0.17963286 -0.64215261]
#  [-0.6490153  -0.02555559 -0.76034601]]
# Translation of alignment:
# [-0.59250927  2.1353822   1.29297689]
# [DEBUG][2024-02-08 00:27:28,805][trajectory.align():216]
# Scale correction: 1.9333135098013936
# Original estimated subtrajectory length: 293
# [DEBUG][2024-02-08 00:27:28,838][sync.associate_trajectories():110]
# Found 293 of max. 293 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:28,838][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:28,840][trajectory.align():214]
# Rotation of alignment:
# [[ 0.02343976 -0.9946848   0.10026325]
#  [-0.77844896  0.04476707  0.62610951]
#  [-0.62727011 -0.09272568 -0.77326203]]
# Translation of alignment:
# [-0.5977055   0.14827443  1.27806134]
# [DEBUG][2024-02-08 00:27:28,840][trajectory.align():216]
# Scale correction: 1.9556310964616697
# Original estimated subtrajectory length: 74
# [DEBUG][2024-02-08 00:27:28,848][sync.associate_trajectories():110]
# Found 74 of max. 74 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:28,848][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:28,849][trajectory.align():214]
# Rotation of alignment:
# [[-0.21437976  0.95871286  0.18684478]
#  [ 0.9056569   0.26675014 -0.32959057]
#  [-0.36582359  0.09855971 -0.92545075]]
# Translation of alignment:
# [-0.61155386  2.02418919  1.45669698]
# [DEBUG][2024-02-08 00:27:28,849][trajectory.align():216]
# Scale correction: 1.53320152521529
# [DEBUG][2024-02-08 00:27:28,885][sync.associate_trajectories():110]
# Found 1947 of max. 1947 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (1947 poses)  with ground truth 1947 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:28,901][metrics.id_pairs_from_delta():469]
# Found 1917 pairs with delta 30 (frames) among 1947 poses using all pairs.
# [DEBUG][2024-02-08 00:27:28,908][metrics.process_data():313]
# Compared 0 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:28,908][metrics.process_data():319]
# Calculating RPE for point distance pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:28,927][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:28,932][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00  1.86853296e-16 -8.88465877e-16]
#  [ 5.91649689e-17  1.00000000e+00 -2.14233455e-16]
#  [ 8.90110933e-16  2.16197941e-16  1.00000000e+00]]
# Translation of alignment:
# [3.05311332e-16 3.77475828e-15 6.43929354e-15]
# [DEBUG][2024-02-08 00:27:28,932][trajectory.align():216]
# Scale correction: 1.0
# /home/slam/Projects/ORB_SLAM3_DRL/PythonAPI/poseEvaluation.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_error_df.rename(columns={'RelativeError': 'BaseRelativeError'}, inplace=True)
# [DEBUG][2024-02-08 00:27:31,429][file_interface.read_tum_trajectory_file():117]
# Loaded 1945 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:31,514][file_interface.read_tum_trajectory_file():117]
# Loaded 30406 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 1945]]
# Original estimated subtrajectory length: 1945
# [DEBUG][2024-02-08 00:27:31,559][sync.associate_trajectories():110]
# Found 1945 of max. 1945 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:31,560][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:31,565][trajectory.align():214]
# Rotation of alignment:
# [[-0.1626282   0.98286589  0.08675661]
#  [ 0.74182173  0.17977062 -0.64605189]
#  [-0.65057866 -0.04070832 -0.75834705]]
# Translation of alignment:
# [-0.5765722   2.15348901  1.26991211]
# [DEBUG][2024-02-08 00:27:31,565][trajectory.align():216]
# Scale correction: 1.9423319934284566
# [DEBUG][2024-02-08 00:27:31,632][sync.associate_trajectories():110]
# Found 1945 of max. 1945 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (1945 poses)  with ground truth 1945 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:31,649][metrics.id_pairs_from_delta():469]
# Found 1915 pairs with delta 30 (frames) among 1945 poses using all pairs.
# [DEBUG][2024-02-08 00:27:31,656][metrics.process_data():313]
# Compared 0 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:31,657][metrics.process_data():319]
# Calculating RPE for point distance pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:31,677][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:31,682][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00  2.38108049e-16 -5.63120697e-16]
#  [-2.20903900e-16  1.00000000e+00 -2.14245683e-16]
#  [ 5.67883913e-16  2.15952538e-16  1.00000000e+00]]
# Translation of alignment:
# [4.44089210e-16 6.66133815e-16 2.66453526e-15]
# [DEBUG][2024-02-08 00:27:31,683][trajectory.align():216]
# Scale correction: 0.9999999999999991
# /home/slam/Projects/ORB_SLAM3_DRL/PythonAPI/poseEvaluation.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_error_df.rename(columns={'RelativeError': 'BaseRelativeError'}, inplace=True)
# [DEBUG][2024-02-08 00:27:35,279][file_interface.read_tum_trajectory_file():117]
# Loaded 1158 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:35,389][file_interface.read_tum_trajectory_file():117]
# Loaded 18437 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 1158]]
# Original estimated subtrajectory length: 1158
# [DEBUG][2024-02-08 00:27:35,408][sync.associate_trajectories():110]
# Found 1158 of max. 1158 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:35,408][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:35,411][trajectory.align():214]
# Rotation of alignment:
# [[-0.94750387  0.28681721 -0.14132339]
#  [ 0.31908722  0.8198628  -0.47540335]
#  [-0.02048807 -0.495541   -0.86834288]]
# Translation of alignment:
# [0.93733526 0.04342231 0.56520591]
# [DEBUG][2024-02-08 00:27:35,412][trajectory.align():216]
# Scale correction: 0.9191843740936062
# [DEBUG][2024-02-08 00:27:35,443][sync.associate_trajectories():110]
# Found 1158 of max. 1158 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (1158 poses)  with ground truth 1158 poses
# ==================================================
# [DEBUG][2024-02-08 00:27:35,453][metrics.id_pairs_from_delta():469]
# Found 1128 pairs with delta 30 (frames) among 1158 poses using all pairs.
# [DEBUG][2024-02-08 00:27:35,472][metrics.process_data():313]
# Compared 1128 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:27:35,473][metrics.process_data():319]
# Calculating RPE for translation part pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:27:35,489][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:35,492][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00  8.02572114e-17  2.26139268e-16]
#  [ 1.31952404e-16  1.00000000e+00  7.07111658e-17]
#  [-3.10316414e-16 -1.48306075e-16  1.00000000e+00]]
# Translation of alignment:
# [ 1.11022302e-16 -3.60822483e-16  7.77156117e-16]
# [DEBUG][2024-02-08 00:27:35,492][trajectory.align():216]
# Scale correction: 0.9999999999999998
# [DEBUG][2024-02-08 00:27:38,867][file_interface.read_tum_trajectory_file():117]
# Loaded 1158 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:27:38,919][file_interface.read_tum_trajectory_file():117]
# Loaded 18437 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 1158]]
# Original estimated subtrajectory length: 1158
# [DEBUG][2024-02-08 00:27:38,938][sync.associate_trajectories():110]
# Found 1158 of max. 1158 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:27:38,938][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:27:38,942][trajectory.align():214]
# Rotation of alignment:
# [[-0.94452388  0.29579007 -0.14276858]
#  [ 0.32740998  0.81350352 -0.48063992]
#  [-0.02602578 -0.50071974 -0.86521812]]
# Translation of alignment:
# ...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,689][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 211
# [DEBUG][2024-02-08 00:28:37,693][sync.associate_trajectories():110]
# Found 211 of max. 211 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,694][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:37,695][trajectory.align():214]
# Rotation of alignment:
# [[-0.19637505  0.97984519  0.03660922]
#  [ 0.86084095  0.19016019 -0.47200844]
#  [-0.46945681 -0.06117596 -0.88083358]]
# Translation of alignment:
# [0.60625241 0.77518861 1.29283384]
# [DEBUG][2024-02-08 00:28:37,695][trajectory.align():216]
# Scale correction: 0.99665422891229
# Original estimated subtrajectory length: 193
# [DEBUG][2024-02-08 00:28:37,702][sync.associate_trajectories():110]
# Found 193 of max. 193 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,703][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:37,704][trajectory.align():214]
# Rotation of alignment:
# [[-0.20409387  0.97827224  0.03645701]
#  [ 0.85880229  0.19679642 -0.47300084]
#  [-0.4698982  -0.06522721 -0.88030739]]
# Translation of alignment:
# [0.60274176 0.78088515 1.28499944]
# [DEBUG][2024-02-08 00:28:37,704][trajectory.align():216]
# Scale correction: 1.0086145306524743
# Original estimated subtrajectory length: 25
# [DEBUG][2024-02-08 00:28:37,709][sync.associate_trajectories():110]
# Found 25 of max. 25 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,709][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 18
# [DEBUG][2024-02-08 00:28:37,711][sync.associate_trajectories():110]
# Found 18 of max. 18 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,712][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:37,713][trajectory.align():214]
# Rotation of alignment:
# [[-0.27690764  0.92060192  0.27534389]
#  [ 0.8031854   0.37904714 -0.45958293]
#  [-0.52746125  0.09389017 -0.84437508]]
# Translation of alignment:
# [0.36364434 1.0369553  1.18759536]
# [DEBUG][2024-02-08 00:28:37,713][trajectory.align():216]
# Scale correction: 1.2422020336256858
# Original estimated subtrajectory length: 19
# [DEBUG][2024-02-08 00:28:37,715][sync.associate_trajectories():110]
# Found 19 of max. 19 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,715][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 178
# [DEBUG][2024-02-08 00:28:37,720][sync.associate_trajectories():110]
# Found 178 of max. 178 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,720][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:37,721][trajectory.align():214]
# Rotation of alignment:
# [[-0.21119197  0.97715576  0.02376069]
#  [ 0.85790435  0.19695775 -0.47456062]
#  [-0.46839949 -0.07983899 -0.87990207]]
# Translation of alignment:
# [0.60491654 0.7738956  1.28420499]
# [DEBUG][2024-02-08 00:28:37,721][trajectory.align():216]
# Scale correction: 1.0075843097239492
# Original estimated subtrajectory length: 14
# [DEBUG][2024-02-08 00:28:37,725][sync.associate_trajectories():110]
# Found 14 of max. 14 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,726][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 211
# [DEBUG][2024-02-08 00:28:37,730][sync.associate_trajectories():110]
# Found 211 of max. 211 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,731][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:37,732][trajectory.align():214]
# Rotation of alignment:
# [[-0.20358234  0.97842994  0.03505838]
#  [ 0.85966945  0.19577865 -0.47184654]
#  [-0.46853246 -0.065921   -0.8809834 ]]
# Translation of alignment:
# [0.60494983 0.78451066 1.29229128]
# [DEBUG][2024-02-08 00:28:37,732][trajectory.align():216]
# Scale correction: 1.0062458061729906
# Original estimated subtrajectory length: 24
# [DEBUG][2024-02-08 00:28:37,738][sync.associate_trajectories():110]
# Found 24 of max. 24 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,738][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 10
# [DEBUG][2024-02-08 00:28:37,740][sync.associate_trajectories():110]
# Found 10 of max. 10 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,740][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:37,741][trajectory.align():214]
# Rotation of alignment:
# [[ 0.09605637 -0.68067389 -0.72626181]
#  [ 0.72731732 -0.45012728  0.51806848]
#  [-0.67954594 -0.57798658  0.45182832]]
# Translation of alignment:
# [1.06180689 0.26729295 0.26323194]
# [DEBUG][2024-02-08 00:28:37,741][trajectory.align():216]
# Scale correction: 1.2007821461709407
# Original estimated subtrajectory length: 17
# [DEBUG][2024-02-08 00:28:37,743][sync.associate_trajectories():110]
# Found 17 of max. 17 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,743][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 33
# [DEBUG][2024-02-08 00:28:37,744][sync.associate_trajectories():110]
# Found 33 of max. 33 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:37,745][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:37,745][trajectory.align():214]
# Rotation of alignment:
# [[-0.26700019  0.96260973  0.0457537 ]
#  [ 0.82009893  0.25189304 -0.51379728]
#  [-0.5061113  -0.09966141 -0.8566907 ]]
# Translation of alignment:
# [0.565067   0.55015853 1.2713157 ]
# [DEBUG][2024-02-08 00:28:37,746][trajectory.align():216]
# Scale correction: 0.8341681728215693
# [DEBUG][2024-02-08 00:28:37,767][sync.associate_trajectories():110]
# Found 1515 of max. 1515 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# Loaded trajectory (1515 poses)  with ground truth 1515 poses
# ==================================================
# [DEBUG][2024-02-08 00:28:37,779][metrics.id_pairs_from_delta():469]
# Found 1485 pairs with delta 30 (frames) among 1515 poses using all pairs.
# [DEBUG][2024-02-08 00:28:37,806][metrics.process_data():313]
# Compared 1485 relative pose pairs, delta = 30 (frames) with all pairs.
# [DEBUG][2024-02-08 00:28:37,806][metrics.process_data():319]
# Calculating RPE for translation part pose relation...
# Loaded trajectory with ground truth
# ==================================================
# [DEBUG][2024-02-08 00:28:37,826][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:37,830][trajectory.align():214]
# Rotation of alignment:
# [[ 1.00000000e+00  4.04225449e-16  1.71322928e-16]
#  [-4.15432661e-17  1.00000000e+00 -2.66885403e-17]
#  [-1.67286597e-16  2.10372812e-17  1.00000000e+00]]
# Translation of alignment:
# [-9.99200722e-16 -1.11022302e-16  0.00000000e+00]
# [DEBUG][2024-02-08 00:28:37,831][trajectory.align():216]
# Scale correction: 0.9999999999999997
# [DEBUG][2024-02-08 00:28:41,292][file_interface.read_tum_trajectory_file():117]
# Loaded 1656 stamps and poses from: ./logs/trajectory.txt
# [DEBUG][2024-02-08 00:28:41,484][file_interface.read_tum_trajectory_file():117]
# Loaded 23417 stamps and poses from: ./logs/ground_truth.txt
# Subtrajectories for alignment: [[0, 194], [194, 215], [215, 680], [680, 706], [706, 915], [915, 1107], [1107, 1313], [1313, 1347], [1347, 1358], [1358, 1359], [1359, 1362], [1362, 1381], [1381, 1395], [1395, 1572], [1572, 1656]]
# Original estimated subtrajectory length: 194
# [DEBUG][2024-02-08 00:28:41,495][sync.associate_trajectories():110]
# Found 194 of max. 194 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,496][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:41,497][trajectory.align():214]
# Rotation of alignment:
# [[-0.18328379  0.98304094 -0.00612933]
#  [ 0.87208437  0.15971232 -0.462559  ]
#  [-0.45373551 -0.09012486 -0.88656731]]
# Translation of alignment:
# [0.63121734 0.79880256 1.30391698]
# [DEBUG][2024-02-08 00:28:41,497][trajectory.align():216]
# Scale correction: 1.0157854373213995
# Original estimated subtrajectory length: 21
# [DEBUG][2024-02-08 00:28:41,502][sync.associate_trajectories():110]
# Found 21 of max. 21 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,502][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 465
# [DEBUG][2024-02-08 00:28:41,510][sync.associate_trajectories():110]
# Found 465 of max. 465 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,511][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:41,513][trajectory.align():214]
# Rotation of alignment:
# [[-0.19208588  0.98099877  0.02728436]
#  [ 0.86651105  0.18258929 -0.46456405]
#  [-0.46071859 -0.06559399 -0.88511909]]
# Translation of alignment:
# [0.61834075 0.77867163 1.29496522]
# [DEBUG][2024-02-08 00:28:41,514][trajectory.align():216]
# Scale correction: 0.9813693701980977
# Original estimated subtrajectory length: 26
# [DEBUG][2024-02-08 00:28:41,524][sync.associate_trajectories():110]
# Found 26 of max. 26 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,524][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# Original estimated subtrajectory length: 209
# [DEBUG][2024-02-08 00:28:41,529][sync.associate_trajectories():110]
# Found 209 of max. 209 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,529][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:41,530][trajectory.align():214]
# Rotation of alignment:
# [[-0.20036976  0.97920632  0.03173249]
#  [ 0.86168139  0.19154928 -0.46990857]
#  [-0.46621577 -0.06681217 -0.88214454]]
# Translation of alignment:
# [0.60675449 0.77457447 1.29493885]
# [DEBUG][2024-02-08 00:28:41,531][trajectory.align():216]
# Scale correction: 0.9732636337745116
# Original estimated subtrajectory length: 192
# [DEBUG][2024-02-08 00:28:41,538][sync.associate_trajectories():110]
# Found 192 of max. 192 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,538][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:41,539][trajectory.align():214]
# Rotation of alignment:
# [[-0.20583816  0.97801011  0.03356906]
#  [ 0.85980446  0.19712769 -0.47103817]
#  [-0.46729748 -0.0680948  -0.88147386]]
# Translation of alignment:
# [0.60395875 0.78070341 1.28808778]
# [DEBUG][2024-02-08 00:28:41,539][trajectory.align():216]
# Scale correction: 0.985849255023994
# Original estimated subtrajectory length: 206
# [DEBUG][2024-02-08 00:28:41,547][sync.associate_trajectories():110]
# Found 206 of max. 206 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,547][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:41,548][trajectory.align():214]
# Rotation of alignment:
# [[ 0.15449742 -0.97442841 -0.16315579]
#  [-0.81847193 -0.21872699  0.53128355]
#  [-0.55338436  0.0514565  -0.83133506]]
# Translation of alignment:
# [ 0.51101009 -0.31302909  1.33394594]
# [DEBUG][2024-02-08 00:28:41,548][trajectory.align():216]
# Scale correction: 1.1252400883015767
# Original estimated subtrajectory length: 34
# [DEBUG][2024-02-08 00:28:41,553][sync.associate_trajectories():110]
# Found 34 of max. 34 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,553][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# [DEBUG][2024-02-08 00:28:41,554][trajectory.align():214]
# Rotation of alignment:
# [[-0.17250941  0.98004074 -0.09879605]
#  [ 0.85469875  0.09907637 -0.5095821 ]
#  [-0.48962286 -0.17234857 -0.8547312 ]]
# Translation of alignment:
# [0.58538416 0.71440846 1.26153583]
# [DEBUG][2024-02-08 00:28:41,554][trajectory.align():216]
# Scale correction: 1.2217985705500218
# Original estimated subtrajectory length: 11
# [DEBUG][2024-02-08 00:28:41,556][sync.associate_trajectories():110]
# Found 11 of max. 11 possible matching timestamps between...
# 	first trajectory
# and:	second trajectory
# ..with max. time diff.: 0.05 (s) and time offset: 0.0 (s).
# [DEBUG][2024-02-08 00:28:41,556][trajectory.align():202]
# Aligning using Umeyama's method... (with scale correction)
# subtrajectory alignment failed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 48
#      44 time.sleep(1)
#      46 poseErrorEvaluator = PoseErrorEvaluator(root_dir, delta, max_diff, max_null_length)
# ---> 48 poseErrorEvaluator.load_trajectory()
#      49 traj_est, traj_ref = poseErrorEvaluator.get_traj_w_gt()
#      51 rpe_metric = poseErrorEvaluator.calculate_RE(pose_relation=metrics.PoseRelation.point_distance)
#
# File ~/Projects/ORB_SLAM3_DRL/PythonAPI/poseEvaluation.py:67, in PoseErrorEvaluator.load_trajectory(self)
#      65 for region in align_regions:
#      66     xyz_sub = xyz[region[0]:region[1], :]
# ---> 67     xyz_sub[0,:] = xyz_sub[1,:]
#      68     xyz_sub[-1,:] = xyz_sub[-2,:]
#      70     quat_sub = quat[region[0]:region[1], :]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
